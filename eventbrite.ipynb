# %%
import pandas as pd
import json
import requests
from pandas.io.json import json_normalize
from datetime import datetime
import numpy as np

# %%
from eventbrite import Eventbrite

# %%
from inspect import getmembers, isfunction

# %%
getmembers(Eventbrite, isfunction)
# Out:
# [('__init__',
#   <function eventbrite.client.Eventbrite.__init__(self, oauth_token, eventbrite_api_url='https://www.eventbriteapi.com/v3/')>),
#  ('api',
#   <function eventbrite.client.Eventbrite.api(self, method, path, data, expand=())>),
#  ('delete',
#   <function eventbrite.client.Eventbrite.delete(self, path, data=None)>),
#  ('delete_event_discounts',
#   <function eventbrite.access_methods.AccessMethodsMixin.delete_event_discounts(self, id, discount_id, **data)>),
#  ('delete_event_public_discounts',
#   <function eventbrite.access_methods.AccessMethodsMixin.delete_event_public_discounts(self, id, discount_id, **data)>),
#  ('delete_user_contact_list',
#   <function eventbrite.access_methods.AccessMethodsMixin.delete_user_contact_list(self, id, contact_list_id, **data)>),
#  ('delete_user_contact_lists_contacts',
#   <function eventbrite.access_methods.AccessMethodsMixin.delete_user_contact_lists_contacts(self, id, contact_list_id, **data)>),
#  ('delete_webhook',
# ...

# %%
eventbrite = Eventbrite('NXLKNSIAVQBMTX374PEI')

# %%
user = eventbrite.get_user()
user
# Out:
# {'emails': [{'email': 'achcmc@gmail.com', 'verified': False, 'primary': True}],
#  'id': '97655118995',
#  'name': 'Gia Tran Hoang',
#  'first_name': 'Gia',
#  'last_name': 'Tran Hoang',
#  'is_public': False,
#  'image_id': None}

# %%
my_id = eventbrite.get_user()['id']
my_id
# Out:
# '97655118995'

# %%
data = json.loads(event_response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-ea1db6884fa6> in <module>
# ----> 1 data = json.loads(event_response)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not EventbriteObject

# %%
event_response = eventbrite.get_organizer_events(id = "6417029961")
dir(event_response)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'clear',
#  'copy',
#  'create',
#  'elapsed',
#  'fromkeys',
#  'get',
#  'headers',
#  'id',
#  'is_list',
#  'is_paginated',
#  'items',
#  'keys',
#  'ok',
#  'pagination',
#  'pk',
#  'pop',
#  'popitem',
#  'pretty',
#  'reason',
#  'request',
#  'resource_uri',
#  'setdefault',
#  'status_code',
#  'type',
#  'update',
#  'values']

# %%
type(event_response)
# Out:
# eventbrite.models.EventbriteObject

# %%
event_response.items().events
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-f5e090c5c5ab> in <module>
# ----> 1 event_response.items().events
#
# AttributeError: 'dict_items' object has no attribute 'events'

# %%
df = pd.DataFrame(list(event_response.items()),columns = ['column1','column2'])
df
# Out:
#       column1                                            column2
# 0  pagination  {'object_count': 1113, 'page_number': 1, 'page...
# 1      events  [{'name': {'text': 'Tony Awards', 'html': 'Ton...

# %%
ab[1]['events']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-4e0aea1b7e57> in <module>
# ----> 1 ab[1]['events']
#
# TypeError: tuple indices must be integers or slices, not str

# %%
df1 = pd.DataFrame(ab[1][1])
df1
# Out:
#  'local': '2014-07-...     97655118995
# 25  {'timezone': 'America/Los_Angeles', 'local': '...     97655118995
# 26  {'timezone': 'America/Los_Angeles', 'local': '...     97655118995
# 27  {'timezone': 'America/Los_Angeles', 'local': '...     97655118995
# 28  {'timezone': 'Asia/Saigon', 'local': '2014-08-...     97655118995
# 29  {'timezone': 'America/Los_Angeles', 'local': '...     97655118995
# 30  {'timezone': 'America/Los_Angeles', 'local': '...     97655118995
# 31  {'timezone': 'Asia/Saigon', 'local': '2014-08-...     97655118995
# 32  {'timezone': 'Asia/Saigon', 'local': '2014-08-...     97655118995
# 33  {'timezone': 'America/Los_Angeles', 'local': '...     97655118995
# 34  {'timezone': 'Asia/Saigon', 'local': '2014-08-...     97655118995
# 35  {'timezone': 'Asia/Saigon', 'local': '2014-08-...     97655118995
# 36  {'timezone': 'Asia/Saigon', 'local': '2014-08-...     97655118995
# 37  {'timezone': 'America/Los_Angeles', 'local': '...     97655118995
# ...

# %%
ab = list(event_response.items())
ab[1]
# Out:
# ormat%2Ccompress&q=75&sharp=10&s=f647e2525ef02919aab8c9f6e696eb7f',
#     'aspect_ratio': '1.405',
#     'edge_color': '#ffffff',
#     'edge_color_set': True}},
#   {'name': {'text': 'Book Club Activities', 'html': 'Book Club Activities'},
#    'description': {'text': 'Speaker: Pilar Quigua, Consulate Officer\r\nCome discuss "The Tell Tale Heart" by Edgar Allen Poe with Ms. Pilar Quigua. Read here: http://xroads.virginia.edu/~HYPER/POE/telltale.html',
#     'html': '<P>Speaker: Pilar Quigua, Consulate Officer</P>\r\n<P>Come discuss "The Tell Tale Heart" by Edgar Allen Poe with Ms. Pilar Quigua. Read here: <A HREF="http://xroads.virginia.edu/~HYPER/POE/telltale.html" REL="nofollow noopener noreferrer">http://xroads.virginia.edu/~HYPER/POE/telltale.html</A></P>'},
#    'url': 'https://www.eventbrite.com/e/book-club-activities-tickets-12847409949',
#    'start': {'timezone': 'Asia/Saigon',
#     'local': '2014-09-09T17:00:00',
#     'utc': '2014-09-09T10:00:00Z'},
# ...

# %%
for key, val in event_response.items():
    print('{0}:\t{1}'.format(key,val))
# Out:
# ale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'create_2.0', 'is_free': True, 'version': None, 'summary': 'A Day Without SpaceDate: Friday, September 5, 10:00 a.m.. - 11:00 a.m.Speaker: Elma Hajric, U.S. Consulate Summer Intern\r\nExpanding your gal', 'logo_id': '7880733', 'organizer_id': '6417029961', 'venue_id': None, 'category_id': '102', 'subcategory_id': '2002', 'format_id': '2', 'id': '12928662979', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/12928662979/', 'is_externally_ticketed': False, 'logo': {'crop_mask': None, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F7880733%2F108461227939%2F1%2Foriginal.gif?auto=format%2Ccompress&q=75&sharp=10&s=448e8b00a5c579fad5729d431a68be37', 'width': None, 'heig
# ...

# %%
data = json.dumps(event_response, indent=4)

# %%
print(data)
# Out:
# AN></P>\r\n<P STYLE=\"line-height: normal;\"><SPAN STYLE=\"font-size: 9.0pt; font-family: 'Verdana','sans-serif';\">Come learn English through films with Mr. Joe Freeman</SPAN></P>\r\n<P STYLE=\"line-height: normal;\"><SPAN STYLE=\"font-size: 9.0pt; font-family: 'Verdana','sans-serif';\"><BR></SPAN></P>\r\n<P STYLE=\"line-height: normal;\">\u00a0</P>\r\n<P STYLE=\"line-height: normal;\"><SPAN STYLE=\"font-family: Verdana, sans-serif;\"><SPAN STYLE=\"font-size: 12px;\"><BR></SPAN></SPAN></P>"
#             },
#             "url": "https://www.eventbrite.com/e/dvd-english-fun-tickets-12847421985",
#             "start": {
#                 "timezone": "Asia/Saigon",
#                 "local": "2014-09-10T17:00:00",
#                 "utc": "2014-09-10T10:00:00Z"
#             },
#             "end": {
#                 "timezone": "Asia/Saigon",
#                 "local": "2014-09-10T18:30:00",
#                 "utc": "2014-09-10T11:30:00Z"
#             },
# ...

# %%
dir(event_response)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'clear',
#  'copy',
#  'create',
#  'elapsed',
#  'fromkeys',
#  'get',
#  'headers',
#  'id',
#  'is_list',
#  'is_paginated',
#  'items',
#  'keys',
#  'ok',
#  'pagination',
#  'pk',
#  'pop',
#  'popitem',
#  'pretty',
#  'reason',
#  'request',
#  'resource_uri',
#  'setdefault',
#  'status_code',
#  'type',
#  'update',
#  'values']

# %%
myit = iter(event_response.events)
myit
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-07891b6b2f0c> in <module>
# ----> 1 myit = iter(event_response.events)
#       2 myit
#
# AttributeError: 'EventbriteObject' object has no attribute 'events'

# %%
df = pd.DataFrame(event_response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-cb34ea1d1e21> in <module>
# ----> 1 df = pd.DataFrame(event_response)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# ...

# %%
event_response = eventbrite.get('/organizations/97655118995/events/')
event_response
# Out:
# ormat%2Ccompress&q=75&sharp=10&s=f647e2525ef02919aab8c9f6e696eb7f',
#     'aspect_ratio': '1.405',
#     'edge_color': '#ffffff',
#     'edge_color_set': True}},
#   {'name': {'text': 'Book Club Activities', 'html': 'Book Club Activities'},
#    'description': {'text': 'Speaker: Pilar Quigua, Consulate Officer\r\nCome discuss "The Tell Tale Heart" by Edgar Allen Poe with Ms. Pilar Quigua. Read here: http://xroads.virginia.edu/~HYPER/POE/telltale.html',
#     'html': '<P>Speaker: Pilar Quigua, Consulate Officer</P>\r\n<P>Come discuss "The Tell Tale Heart" by Edgar Allen Poe with Ms. Pilar Quigua. Read here: <A HREF="http://xroads.virginia.edu/~HYPER/POE/telltale.html" REL="nofollow noopener noreferrer">http://xroads.virginia.edu/~HYPER/POE/telltale.html</A></P>'},
#    'url': 'https://www.eventbrite.com/e/book-club-activities-tickets-12847409949',
#    'start': {'timezone': 'Asia/Saigon',
#     'local': '2014-09-09T17:00:00',
#     'utc': '2014-09-09T10:00:00Z'},
# ...

# %%
events
# Out:
# {'status_code': 404,
#  'error_description': 'The path you requested does not exist.',
#  'error': 'NOT_FOUND'}
